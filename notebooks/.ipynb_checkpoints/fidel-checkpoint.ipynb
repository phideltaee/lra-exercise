# %%
import os, sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from utils.helpers import launch_env, wrap_env, view_results_ipython, force_done
from utils.helpers import SteeringToWheelVelWrapper, ResizeWrapper, ImgWrapper

import numpy as np

import torch
import torch.nn as nn
from torch import optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# INFO:aido-protocols:aido-protocols 5.0.18
# 17:29:18|zj|__init__.py:4|<module>(): zuper-ipce 5.1.0
# 17:29:18|zuper-typing|__init__.py:5|<module>(): zuper-typing 5.0.12
# 17:29:18|zuper-commons|__init__.py:9|<module>(): zuper-commons 5.0.6
# 17:29:18|zuper-typing|zeneric2.py:48|<module>(): In Python 3.6
# 17:29:18|zuper-nodes|__init__.py:8|<module>(): zuper-nodes 5.0.8

# %% [markdown]
# # Generating Data from a Teacher
#
# In order to use imitation learning in practice, we need to have _demonstrations_. However, demonstrations need to be gathered; in general, we can collect the demonstrations that we need in one of four ways:
#
# * Human demonstrator teleoperating the robot
# * Data logs or historical data
# * Learned policy (i.e from reinforcement learning) is rolled out
# * Hard-coded expert is rolled out
#
# While these trajectories can be gathered on real robots, to speed up collection, we work mainly in simulation. Duckietown has a [vast](https://logs.duckietown.org) collection of logs gathered over years of running programs on Duckiebots, but here, we focus on the last data collection method: a hard-coded expert.
#
# **<font color='red'>Question 1:</font> What are some pros and cons of each approach? List two pros and two cons for each of the four methods listed above.**
#
# We first introduce a _pure-pursuit expert_ - often, in robotic imitation learning, we have controllers to control many of our robots and systems; a pure-pursuit expert is about the simplest controller that we can have for a Duckiebot.
#
# Our expert drives with ground-truth state data; while more complicated controllers incorporate and fuse observational data to estimate a state, we use data that'd a robot would not normally have access to.

# %%
class PurePursuitExpert:
    def __init__(self, env, ref_velocity=0.04, position_threshold=0.8, gain=10,
                 following_distance=0.3, max_iterations=1000):
        self.env = env.unwrapped
        self.following_distance = following_distance
        self.max_iterations = max_iterations
        self.ref_velocity = ref_velocity
        self.gain = gain
        self.position_threshold = position_threshold

    def predict(self, observation):  
        # Our expert drives with "cheating" data, something your implementation will not have access to
        closest_point, closest_tangent = self.env.closest_curve_point(self.env.cur_pos, self.env.cur_angle)

        iterations = 0
        lookup_distance = self.following_distance
        curve_point = None
        while iterations < self.max_iterations:
            # Project a point ahead along the curve tangent,
            # then find the closest point to to that
            follow_point = closest_point + closest_tangent * lookup_distance
            curve_point, _ = self.env.closest_curve_point(follow_point, self.env.cur_angle)

            # If we have a valid point on the curve, stop
            if curve_point is not None:
                break

            iterations += 1
            lookup_distance *= 0.5

        # Compute a normalized vector to the curve point
        point_vec = curve_point - self.env.cur_pos
        point_vec /= np.linalg.norm(point_vec)

        dot = np.dot(self.env.get_right_vec(), point_vec)
        steering = self.gain * -dot

        return self.ref_velocity, steering

# %%
nsteps = 2500

# %%
local_env = launch_env()
local_env = wrap_env(local_env)
local_env = ResizeWrapper(local_env)
local_env = ImgWrapper(local_env)

local_env.reset()
wrapper = SteeringToWheelVelWrapper()

# Create an demonstrator
expert = PurePursuitExpert(env=local_env,ref_velocity=0.4, position_threshold=0.8, 
                           gain=5, following_distance=0.8)

observations = []
actions = []

# Collect samples

for steps in range(0, nsteps):
 2), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:50:36|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:50:36|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:50:36|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [2.6764202  0.         1.12366736]
# 18:50:36|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [2.72105902 0.         1.03698619]
# 18:50:36|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [2.63178138 0.         1.21034854]
# 18:50:36|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [2.78043761 0.         1.17723395]
# 18:50:36|gym-duckietown|simulator.py:1140|_drivable_pos(): [2.34877621 0.         0.54381577] corresponds to tile at (4, 0) which is not drivable: {'coords': (4, 0), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:50:36|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:50:36|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:50:36|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [2.37123782 0.         0.65863944]
# 18:50:36|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [2.27555142 0.         0.67735745]
# 18:50:36|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [2.46692421 0.         0.63992143]
# 18:50:36|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [2.34877621 0.         0.54381577]
# 18:50:36|gym-duckietown|simulator.py:1140|_drivable_pos(): [2.65272699 0.         1.23268696] corresponds to tile at (4, 2) which is not drivable: {'coords': (4, 2), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:50:36|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:50:36|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:50:36|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [2.67066935 0.         1.1368521 ]
# 18:50:36|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [2.65272699 0.         1.23268696]
# 18:50:36|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [2.68861172 0.         1.04101723]
# 18:50:36|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [2.55566752 0.         1.11532126]
# 18:50:36|gym-duckietown|simulator.py:1140|_drivable_pos(): [2.50825664 0.         0.54140564] corresponds to tile at (4, 0) which is not drivable: {'coords': (4, 0), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:50:36|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:50:36|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:50:36|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [2.47380268 0.         0.63261515]
# 18:50:36|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [2.43934872 0.         0.72382466]
# 18:50:36|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [2.50825664 0.         0.54140564]
# 18:50:36|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [2.36435127 0.         0.5912704 ]
# 18:50:36|gym-duckietown|simulator.py:1140|_drivable_pos(): [2.53990656 0.         1.17455069] corresponds to tile at (4, 2) which is not drivable: {'coords': (4, 2), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:50:36|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:50:36|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:50:36|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [2.5736877  0.         1.06253358]
# 18:50:36|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [2.6670353  0.         1.09068453]
# 18:50:36|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [2.48034011 0.         1.03438262]
# 18:50:36|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [2.53990656 0.         1.17455069]
# 18:50:36|gym-duckietown|simulator.py:559|reset(): Starting at [2.8802118  0.         0.83154698] 0.03494804900834834
# Done!

# %%
view_results_ipython(local_env)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9f9a195dfd8b> in <module>
# ----> 1 view_results_ipython(local_env)
#
# NameError: name 'view_results_ipython' is not defined

# %% [markdown]
# **<font color='red'>Question 2:</font> When you visualize the results, what are two major issues? Play with the expert's code and the execution code above, and list five changes that you tried, as well as their _qualitative_ effects on performance (i.e cover the most distance). DO NOT RESEED THE ENVIRONMENT**

# %% [markdown]
# # Defining a Model
#
# While the above expert isn't great, it's a start. What's best is that we now have image `observations` and real-valued `actions` that we can use to train a neural network in Pytorch. Our imitation learner will driver directly from observations, and will be trained with a popular imitation learning loss: Mean Squared Error.

# %%
class Model(nn.Module):
    def __init__(self, action_dim, max_action):
        super(Model, self).__init__()

        # TODO: You'll need to change this!
        flat_size = 31968
        
        ###########################################
        # QUESTION 3. What does the next line do? #
        ###########################################
        # these define the activation functions for the 
        self.lr = nn.LeakyReLU()
        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()

        self.conv1 = nn.Conv2d(3, 32, 8, stride=2)
        self.conv2 = nn.Conv2d(32, 32, 4, stride=2)

        self.bn1 = nn.BatchNorm2d(32)
        self.bn2 = nn.BatchNorm2d(32)

        #Changed from 0.1
        self.dropout = nn.Dropout(.2)

        self.lin1 = nn.Linear(flat_size, 100)
        self.lin2 = nn.Linear(100, action_dim)

        self.max_action = max_action

    def forward(self, x):
        x = self.bn1(self.relu(self.conv1(x)))
        x = self.bn2(self.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)  # flatten
        x = self.dropout(x)
        x = self.lr(self.lin1(x))

        x = self.lin2(x)
        x = self.max_action * self.tanh(x)
        
        return x

# %% [markdown]
# # Training from the Teacher Data
#
# We can then write our _training loop_ : the piece of code that implements the process of stochastic gradient descent to minimize the loss between our network's predicted actions and those implemented by our expert.

# %%
nepochs = 400
batchsize = 4

actions = np.array(actions)
observations = np.array(observations)

model = Model(action_dim=2, max_action=1.)
model.train().to(device)

# weight_decay is L2 regularization, helps avoid overfitting
optimizer = optim.SGD(
    model.parameters(),
    lr=0.001,
    weight_decay=0.5e-3
)

avg_loss = 0
for epoch in range(nepochs):
    optimizer.zero_grad()

    batch_indices = np.random.randint(0, observations.shape[0], (batchsize))
    obs_batch = torch.from_numpy(observations[batch_indices]).float().to(device)
    act_batch = torch.from_numpy(actions[batch_indices]).float().to(device)

    model_actions = model(obs_batch)

    loss = (model_actions - act_batch).norm(2).mean()
    loss.backward()
    optimizer.step()

    loss = loss.data.item()
    avg_loss = avg_loss * 0.995 + loss * 0.005

    print('epoch %d, loss=%.3f' % (epoch, avg_loss))

    # Periodically save the trained model
    if epoch % 5 == 0:
        torch.save(model.state_dict(), 'models/imitate.pt')
        
print('\nDone!\n')
# Out:
# epoch 0, loss=0.006
# epoch 1, loss=0.009
# epoch 2, loss=0.013
# epoch 3, loss=0.015
# epoch 4, loss=0.017
# epoch 5, loss=0.021
# epoch 6, loss=0.023
# epoch 7, loss=0.026
# epoch 8, loss=0.029
# epoch 9, loss=0.030
# epoch 10, loss=0.031
# epoch 11, loss=0.034
# epoch 12, loss=0.036
# epoch 13, loss=0.038
# epoch 14, loss=0.041
# epoch 15, loss=0.042
# epoch 16, loss=0.044
# epoch 17, loss=0.045
# epoch 18, loss=0.047
# epoch 19, loss=0.048
# epoch 20, loss=0.049
# epoch 21, loss=0.051
# epoch 22, loss=0.053
# epoch 23, loss=0.054
# epoch 24, loss=0.055
# epoch 25, loss=0.056
# epoch 26, loss=0.058
# epoch 27, loss=0.059
# epoch 28, loss=0.061
# epoch 29, loss=0.063
# epoch 30, loss=0.064
# epoch 31, loss=0.065
# epoch 32, loss=0.067
# epoch 33, loss=0.068
# epoch 34, loss=0.069
# epoch 35, loss=0.070
# epoch 36, loss=0.072
# epoch 37, loss=0.075
# epoch 38, loss=0.076
# epoch 39, loss=0.078
# epoch 40, loss=0.080
# epoch 41, loss=0.080
# epoch 42, loss=0.081
# epoch 43, loss=0.082
# epoch 44, loss=0.083
# epoch 45, loss=0.085
# epoch 46, loss=0.087
# epoch 47, loss=0.088
# epoch 48, loss=0.089
# epoch 49, loss=0.090
# epoch 50, loss=0.091
# epoch 51, loss=0.092
# epoch 52, loss=0.093
# epoch 53, loss=0.094
# epoch 54, loss=0.094
# epoch 55, loss=0.095
# epoch 56, loss=0.096
# epoch 57, loss=0.097
# epoch 58, loss=0.098
# epoch 59, loss=0.099
# epoch 60, loss=0.100
# epoch 61, loss=0.101
# epoch 62, loss=0.101
# epoch 63, loss=0.102
# epoch 64, loss=0.102
# epoch 65, loss=0.103
# epoch 66, loss=0.104
# epoch 67, loss=0.105
# epoch 68, loss=0.106
# epoch 69, loss=0.107
# epoch 70, loss=0.108
# epoch 71, loss=0.109
# epoch 72, loss=0.109
# epoch 73, loss=0.111
# epoch 74, loss=0.111
# epoch 75, loss=0.111
# epoch 76, loss=0.112
# epoch 77, loss=0.112
# epoch 78, loss=0.113
# epoch 79, loss=0.114
# epoch 80, loss=0.115
# epoch 303, loss=0.168
# epoch 304, loss=0.168
# epoch 305, loss=0.167
# epoch 306, loss=0.168
# epoch 307, loss=0.168
# epoch 308, loss=0.168
# epoch 309, loss=0.168
# epoch 310, loss=0.167
# epoch 311, loss=0.167
# epoch 312, loss=0.167
# epoch 313, loss=0.167
# epoch 314, loss=0.167
# epoch 315, loss=0.166
# epoch 316, loss=0.166
# epoch 317, loss=0.166
# epoch 318, loss=0.166
# epoch 319, loss=0.166
# epoch 320, loss=0.167
# epoch 321, loss=0.167
# epoch 322, loss=0.167
# epoch 323, loss=0.166
# epoch 324, loss=0.166
# epoch 325, loss=0.166
# epoch 326, loss=0.166
# epoch 327, loss=0.166
# epoch 328, loss=0.165
# epoch 329, loss=0.165
# epoch 330, loss=0.165
# epoch 331, loss=0.166
# epoch 332, loss=0.165
# epoch 333, loss=0.165
# epoch 334, loss=0.165
# epoch 335, loss=0.166
# epoch 336, loss=0.166
# epoch 337, loss=0.166
# epoch 338, loss=0.166
# epoch 339, loss=0.166
# epoch 340, loss=0.166
# epoch 341, loss=0.166
# epoch 342, loss=0.166
# epoch 343, loss=0.165
# epoch 344, loss=0.165
# epoch 345, loss=0.165
# epoch 346, loss=0.165
# epoch 347, loss=0.164
# epoch 348, loss=0.165
# epoch 349, loss=0.164
# epoch 350, loss=0.164
# epoch 351, loss=0.165
# epoch 352, loss=0.164
# epoch 353, loss=0.164
# epoch 354, loss=0.164
# epoch 355, loss=0.164
# epoch 356, loss=0.164
# epoch 357, loss=0.163
# epoch 358, loss=0.163
# epoch 359, loss=0.163
# epoch 360, loss=0.163
# epoch 361, loss=0.163
# epoch 362, loss=0.163
# epoch 363, loss=0.163
# epoch 364, loss=0.163
# epoch 365, loss=0.163
# epoch 366, loss=0.164
# epoch 367, loss=0.164
# epoch 368, loss=0.164
# epoch 369, loss=0.164
# epoch 370, loss=0.164
# epoch 371, loss=0.163
# epoch 372, loss=0.164
# epoch 373, loss=0.163
# epoch 374, loss=0.163
# epoch 375, loss=0.163
# epoch 376, loss=0.163
# epoch 377, loss=0.163
# epoch 378, loss=0.163
# epoch 379, loss=0.163
# epoch 380, loss=0.162
# epoch 381, loss=0.162
# epoch 382, loss=0.162
# epoch 383, loss=0.162
# epoch 384, loss=0.162
# epoch 385, loss=0.162
# epoch 386, loss=0.163
# epoch 387, loss=0.162
# epoch 388, loss=0.162
# epoch 389, loss=0.162
# epoch 390, loss=0.162
# epoch 391, loss=0.162
# epoch 392, loss=0.162
# epoch 393, loss=0.162
# epoch 394, loss=0.162
# epoch 395, loss=0.162
# epoch 396, loss=0.161
# epoch 397, loss=0.161
# epoch 398, loss=0.161
# epoch 399, loss=0.161
#
# Done!

# %% [markdown]
# **<font color='red'>Question 3:</font> Qualitatively explain at least 2 changes you made to both the expert and network (architecture, hyperparameters, episode lengths, number of training episodes / epochs, etc.) (including partial points if we find that you didn't make changes to any part of our code - hyperparameters, network, etc.)**
#
#
# **<font color='red'>Question 4:</font> Explain the issues with the imitation learning loop above. Specifically, comment on the loss function and training objective. Explain at least one issue, and propose a way that could help solve the issues you've brought up.**

# %%
force_done(local_env)
local_env = launch_env()
local_env = wrap_env(local_env)
local_env = ResizeWrapper(local_env)
local_env = ImgWrapper(local_env)

obs = local_env.reset()

done = False
rewards = []
nsteps = 500
for steps in range(0, nsteps):
    obs = torch.from_numpy(obs).float().to(device).unsqueeze(0)
    action = model(obs)
    action = action.squeeze().data.cpu().numpy()
    obs, reward, done, info = local_env.step(action) 
    rewards.append(reward)
    
    if done:
        local_env.reset()
        print("Reset!")

print(info)
        
local_env.close()


print("\nDone!\n")
# Out:
# 18:53:47|gym-duckietown|graphics.py:121|create_frame_buffers(): Falling back to non-multisampled frame buffer
# 18:53:47|gym-duckietown|graphics.py:121|create_frame_buffers(): Falling back to non-multisampled frame buffer
# 18:53:47|gym-duckietown|simulator.py:578|_load_map(): loading map file "/duckietown/simulation/src/gym_duckietown/maps/loop_empty.yaml"
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.13719561 0.         1.88880899] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.0873995 0.        1.9726338]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [4.03760339 0.         2.0564586 ]
# 18:53:47|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [4.13719561 0.         1.88880899]
# 18:53:47|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.98680973 0.         1.91287847]
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.10908822 0.         2.30642426] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.0793971  0.         2.21355507]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [4.10908822 0.         2.30642426]
# 18:53:47|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [4.04970598 0.         2.12068587]
# 18:53:47|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.96795406 0.         2.24918441]
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.47880119 0.         2.23809688] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.54467288 0.         2.16621385]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.47880119 0.         2.23809688]
# 18:53:47|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.61054457 0.         2.09433082]
# 18:53:47|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.45841324 0.         2.08716782]
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.11902599 0.         2.07053136] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.05777514 0.         2.14639032]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [4.11902599 0.         2.07053136]
# 18:53:47|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.99652428 0.         2.22224929]
# 18:53:47|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [4.14880589 0.         2.21989135]
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.11072664 0.         2.23740683] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.06163269 0.         2.15316887]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [4.11072664 0.         2.23740683]
# 18:53:47|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [4.01253874 0.         2.0689309 ]
# 18:53:47|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.96054713 0.         2.2120816 ]
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.09719614 0.         2.20147659] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.00591875 0.         2.23575032]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [4.09719614 0.         2.20147659]
# 18:53:47|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.91464137 0.         2.27002405]
# 18:53:47|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [4.04704723 0.         2.34528318]
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.48173779 0.         2.07668522] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.59826268 0.         2.08721855]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.5894849  0.         2.18432262]
# 18:53:47|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.60704045 0.         1.99011448]
# 18:53:47|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.48173779 0.         2.07668522]
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.48172154 0.         1.84866924] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.57292165 0.         1.88314807]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.48172154 0.         1.84866924]
# 18:53:47|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.66412176 0.         1.91762689]
# 18:53:47|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.61429624 0.         1.77370793]
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.50690495 0.         2.23654429] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.6172817  0.         2.19773742]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.64962075 0.         2.28971804]
# 18:53:47|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.58494264 0.         2.10575679]
# 18:53:47|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.50690495 0.         2.23654429]
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.11050548 0.         2.28364106] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.00116556 0.         2.24200236]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [4.03586448 0.         2.15088576]
# 18:53:47|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.96646664 0.         2.33311896]
# 18:53:47|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [4.11050548 0.         2.28364106]
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.50186974 0.         2.10261411] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.5769519  0.         2.04041348]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.50186974 0.         2.10261411]
# 18:53:47|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.65203407 0.         1.97821284]
# 18:53:47|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.50231114 0.         1.95031488]
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.47260658 0.         1.77460142] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.58708306 0.         1.75043253]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.6072238 0.        1.8458296]
# 18:53:47|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.56694232 0.         1.65503546]
# 18:53:47|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.47260658 0.         1.77460142]
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.09934153 0.         1.85301864] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.02300463 0.         1.79236447]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.94666773 0.         1.7317103 ]
# 18:53:47|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [4.09934153 0.         1.85301864]
# 18:53:47|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [4.09578963 0.         1.70076019]
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.17105167 0.         1.80077003] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.09036721 0.         1.85550821]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [4.00968276 0.         1.9102464 ]
# 18:53:47|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [4.17105167 0.         1.80077003]
# 18:53:47|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [4.02468139 0.         1.75868687]
# 18:53:47|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.49620504 0.         2.20742184] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:53:47|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:53:47|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:53:47|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.57500004 0.         2.14999713]
# 18:53:47|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3
gym-duckietown|simulator.py:1140|_drivable_pos(): [2.98509747 0.         1.19273652] corresponds to tile at (5, 2) which is not drivable: {'coords': (5, 2), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:54:05|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:54:05|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:54:05|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.05094654 0.         1.12083277]
# 18:54:05|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.11679562 0.         1.04892902]
# 18:54:05|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [2.98509747 0.         1.19273652]
# 18:54:05|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.13723104 0.         1.19985166]
# 18:54:05|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.40519482 0.         1.20966763] corresponds to tile at (5, 2) which is not drivable: {'coords': (5, 2), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:54:05|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:54:05|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:54:05|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.37939712 0.         1.11564249]
# 18:54:05|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.40519482 0.         1.20966763]
# 18:54:05|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.35359941 0.         1.02161734]
# 18:54:05|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.26656694 0.         1.14659973]
# 18:54:05|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.28669595 0.         1.2239658 ] corresponds to tile at (5, 2) which is not drivable: {'coords': (5, 2), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:54:05|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:54:05|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:54:05|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.31772931 0.         1.13153647]
# 18:54:05|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.28669595 0.         1.2239658 ]
# 18:54:05|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.34876267 0.         1.03910715]
# 18:54:05|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.20681412 0.         1.09429644]
# 18:54:05|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.32870397 0.         0.56173371] corresponds to tile at (5, 0) which is not drivable: {'coords': (5, 0), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:54:05|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:54:05|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:54:05|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.34768548 0.         0.65736818]
# 18:54:05|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.36666698 0.         0.75300265]
# 18:54:05|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.32870397 0.         0.56173371]
# 18:54:05|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.23292411 0.         0.68014598]
# 18:54:05|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.30655235 0.         1.18763146] corresponds to tile at (5, 2) which is not drivable: {'coords': (5, 2), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:54:05|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:54:05|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:54:05|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.22934714 0.         1.12808647]
# 18:54:05|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.30655235 0.         1.18763146]
# 18:54:05|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.15214192 0.         1.06854149]
# 18:54:05|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.15789316 0.         1.22073273]
# 18:54:05|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.43806951 0.         0.50424435] corresponds to tile at (5, 0) which is not drivable: {'coords': (5, 0), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:54:05|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:54:05|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:54:05|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.46047635 0.         0.59913473]
# 18:54:05|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.43806951 0.         0.50424435]
# 18:54:05|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.48288319 0.         0.6940251 ]
# 18:54:05|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.5743448  0.         0.57224652]
# 18:54:05|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.07292186 0.         0.58314652] corresponds to tile at (5, 0) which is not drivable: {'coords': (5, 0), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:54:05|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:54:05|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:54:05|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.07292186 0.         0.58314652]
# 18:54:05|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.09477079 0.         0.48812613]
# 18:54:05|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.05107293 0.         0.67816691]
# 18:54:05|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.18694633 0.         0.60936523]
# 18:54:05|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.13790972 0.         1.18451757] corresponds to tile at (5, 2) which is not drivable: {'coords': (5, 2), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1, 1, 1])}
# 18:54:05|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:54:05|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:54:05|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.2163532  0.         1.12661359]
# 18:54:05|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.13790972 0.         1.18451757]
# 18:54:05|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.29479668 0.         1.06870962]
# 18:54:05|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.14686844 0.         1.03248141]
# 18:54:05|gym-duckietown|simulator.py:559|reset(): Starting at [3.42800181 0.         0.96675439] 0.03283258105572982
# Reset!
# {'Simulator': {'action': [0.50564337, 0.49128446], 'lane_position': {'dist': -0.07664491667525605, 'dot_dir': 0.987074670420132, 'angle_deg': -9.222047162193872, 'angle_rad': -0.1609550867544826}, 'robot_speed': 0.29857731501100476, 'proximity_penalty': 0.0, 'cur_pos': [3.761992665057099, 0.0, 1.1587016141755275], 'cur_angle': -1.383795027392724, 'wheel_velocities': [0.60677207, 0.5895414], 'timestamp': 1.8000000000000023, 'tile_coords': [6, 1], 'msg': ''}}
#
# Done!

# %%
view_results_ipython(local_env)
# Out:
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>

# %% [markdown]
# **<font color='red'>Question 5:</font> Copy the value of _info_ , after simulating for 500 steps. If your simulation fails earlier, save the results _before_ the failure (i.e. when the simulation returns `done = True`.  DO NOT RESEED THE ENVIRONMENT**

# %% [markdown]
# # A nastier environment
#
# Once your solution is able to pass a curve while staying in the lane, you can try to see what happens if you modify the test environment with respect to the one used to generate the training dataset.
#
# To do this, create a new environment called *new_environment* by using the **launch_env()** function as above. This time passing the argument *domain_rand=True*. Basically it randomizes the environment. Once you have the new environment, run again the model without retraining.
#
# Then, visualize the results.
#
# **<font color='red'>Question 6:</font> Comment the performance of your solution on the new environment, name two reasons that justify the performance.**

# %%
# TODO: Run again the agent in the new randomized environment as explained above

new_env = launch_env(domain_rand=True)
new_env = wrap_env(new_env)
new_env = ResizeWrapper(new_env)
new_env = ImgWrapper(new_env)

obs = new_env.reset()

done = False
rewards = []
nsteps = 300
for steps in range(0, nsteps):
    obs = torch.from_numpy(obs).float().to(device).unsqueeze(0)
    action = model(obs)
    action = action.squeeze().data.cpu().numpy()
    obs, reward, done, info = new_env.step(action) 
    rewards.append(reward)
    
    if done:
        new_env.reset()

new_env.close()

print("\nDone!\n")
# Out:
# 18:39:11|gym-duckietown|graphics.py:121|create_frame_buffers(): Falling back to non-multisampled frame buffer
# 18:39:11|gym-duckietown|graphics.py:121|create_frame_buffers(): Falling back to non-multisampled frame buffer
# 18:39:11|gym-duckietown|simulator.py:578|_load_map(): loading map file "/duckietown/simulation/src/gym_duckietown/maps/loop_empty.yaml"
# 18:39:11|gym-duckietown|graphics.py:60|load_texture(): loading texture "curve_left_3.png"
# 18:39:11|gym-duckietown|simulator.py:1140|_drivable_pos(): [0.54829264 0.         2.5248345 ] corresponds to tile at (0, 4) which is not drivable: {'coords': (0, 4), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([0.82985124, 1.15541818, 0.90280541])}
# 18:39:11|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:39:11|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:39:11|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [0.63698078 0.         2.48432939]
# 18:39:11|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [0.54829264 0.         2.5248345 ]
# 18:39:11|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [0.72566892 0.         2.44382429]
# 18:39:11|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [0.58837465 0.         2.37790362]
# 18:39:11|gym-duckietown|simulator.py:1140|_drivable_pos(): [1.22079922 0.         2.29800489] corresponds to tile at (2, 3) which is not drivable: {'coords': (2, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1.18267354, 0.86106281, 1.04146969])}
# 18:39:11|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:39:11|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:39:11|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [1.14835513 0.         2.36325903]
# 18:39:11|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [1.07591104 0.         2.42851318]
# 18:39:11|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [1.22079922 0.         2.29800489]
# 18:39:11|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [1.07005016 0.         2.27632613]
# 18:39:11|gym-duckietown|simulator.py:1140|_drivable_pos(): [0.57294313 0.         2.84936047] corresponds to tile at (0, 4) which is not drivable: {'coords': (0, 4), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([0.82985124, 1.15541818, 0.90280541])}
# 18:39:11|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:39:11|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:39:11|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [0.65739128 0.         2.93033892]
# 18:39:11|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [0.58990923 0.         3.00071238]
# 18:39:11|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [0.72487332 0.         2.85996546]
# 18:39:11|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [0.57294313 0.         2.84936047]
# 18:39:11|gym-duckietown|simulator.py:1140|_drivable_pos(): [0.5739956 0.        2.4455528] corresponds to tile at (0, 4) which is not drivable: {'coords': (0, 4), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([0.82985124, 1.15541818, 0.90280541])}
# 18:39:11|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:39:11|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:39:11|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [0.66656548 0.         2.37399991]
# 18:39:11|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [0.72619289 0.         2.45114148]
# 18:39:11|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos:
gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [1.90319062 0.         1.06257775]
# 18:39:25|gym-duckietown|simulator.py:1140|_drivable_pos(): [1.78988284 0.         1.22750266] corresponds to tile at (3, 2) which is not drivable: {'coords': (3, 2), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1.04122034, 0.90729052, 0.85726043])}
# 18:39:25|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:39:25|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:39:25|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [1.8528545  0.         1.15306598]
# 18:39:25|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [1.78988284 0.         1.22750266]
# 18:39:25|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [1.91582616 0.         1.07862929]
# 18:39:25|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [1.76353048 0.         1.07749999]
# 18:39:25|gym-duckietown|simulator.py:1140|_drivable_pos(): [2.02460878 0.         0.50043768] corresponds to tile at (3, 0) which is not drivable: {'coords': (3, 0), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([0.80318537, 1.08869665, 0.81525536])}
# 18:39:25|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:39:25|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:39:25|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [2.03728379 0.         0.59711029]
# 18:39:25|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [2.02460878 0.         0.50043768]
# 18:39:25|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [2.04995881 0.         0.6937829 ]
# 18:39:25|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [2.15329093 0.         0.58190027]
# 18:39:25|gym-duckietown|simulator.py:1140|_drivable_pos(): [2.14208763 0.         0.55959076] corresponds to tile at (3, 0) which is not drivable: {'coords': (3, 0), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([0.80318537, 1.08869665, 0.81525536])}
# 18:39:25|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:39:25|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:39:25|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [2.17658466 0.         0.65078399]
# 18:39:25|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [2.21108169 0.         0.74197722]
# 18:39:25|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [2.14208763 0.         0.55959076]
# 18:39:25|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [2.06715279 0.         0.69218042]
# 18:39:25|gym-duckietown|simulator.py:1140|_drivable_pos(): [2.28525313 0.         0.52097295] corresponds to tile at (3, 0) which is not drivable: {'coords': (3, 0), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([0.80318537, 1.08869665, 0.81525536])}
# 18:39:25|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:39:25|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:39:25|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [2.29486793 0.         0.63757722]
# 18:39:25|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [2.19769771 0.         0.64558956]
# 18:39:25|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [2.39203816 0.         0.62956488]
# 18:39:25|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [2.28525313 0.         0.52097295]
# 18:39:25|gym-duckietown|simulator.py:1140|_drivable_pos(): [2.21600015 0.         0.5532934 ] corresponds to tile at (3, 0) which is not drivable: {'coords': (3, 0), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([0.80318537, 1.08869665, 0.81525536])}
# 18:39:25|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:39:25|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:39:25|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [2.15630702 0.         0.63038413]
# 18:39:25|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [2.21600015 0.         0.5532934 ]
# 18:39:25|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [2.0966139  0.         0.70747486]
# 18:39:25|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [2.2488159  0.         0.70201588]
# 18:39:25|gym-duckietown|simulator.py:1140|_drivable_pos(): [2.04309221 0.         1.17431775] corresponds to tile at (3, 2) which is not drivable: {'coords': (3, 2), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7fb2c32047b8>, 'color': array([1.04122034, 0.90729052, 0.85726043])}
# 18:39:25|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:39:25|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:39:25|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [2.07179671 0.         1.08113888]
# 18:39:25|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [2.04309221 0.         1.17431775]
# 18:39:25|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [2.10050121 0.         0.98796001]
# 18:39:25|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [1.95998207 0.         1.04669348]
# 18:39:25|gym-duckietown|simulator.py:559|reset(): Starting at [2.2637908  0.         0.91262603] 6.233710116996369
# Done!

# %%
# TODO: visualize the results
view_results_ipython(new_env)
# Out:
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>
