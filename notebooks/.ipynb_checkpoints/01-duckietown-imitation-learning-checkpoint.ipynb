# %%
import os, sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from utils.helpers import launch_env, wrap_env, view_results_ipython, force_done
from utils.helpers import SteeringToWheelVelWrapper, ResizeWrapper, ImgWrapper

import numpy as np

import torch
import torch.nn as nn
from torch import optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# INFO:aido-protocols:aido-protocols 5.0.18
# 18:29:32|zj|__init__.py:4|<module>(): zuper-ipce 5.1.0
# 18:29:32|zuper-typing|__init__.py:5|<module>(): zuper-typing 5.0.12
# 18:29:32|zuper-commons|__init__.py:9|<module>(): zuper-commons 5.0.6
# 18:29:32|zuper-typing|zeneric2.py:48|<module>(): In Python 3.6
# 18:29:32|zuper-nodes|__init__.py:8|<module>(): zuper-nodes 5.0.8

# %% [markdown]
# # Generating Data from a Teacher
#
# In order to use imitation learning in practice, we need to have _demonstrations_. However, demonstrations need to be gathered; in general, we can collect the demonstrations that we need in one of four ways:
#
# * Human demonstrator teleoperating the robot
# * Data logs or historical data
# * Learned policy (i.e from reinforcement learning) is rolled out
# * Hard-coded expert is rolled out
#
# While these trajectories can be gathered on real robots, to speed up collection, we work mainly in simulation. Duckietown has a [vast](https://logs.duckietown.org) collection of logs gathered over years of running programs on Duckiebots, but here, we focus on the last data collection method: a hard-coded expert.
#
# **<font color='red'>Question 1:</font> What are some pros and cons of each approach? List two pros and two cons for each of the four methods listed above.**
#
# We first introduce a _pure-pursuit expert_ - often, in robotic imitation learning, we have controllers to control many of our robots and systems; a pure-pursuit expert is about the simplest controller that we can have for a Duckiebot.
#
# Our expert drives with ground-truth state data; while more complicated controllers incorporate and fuse observational data to estimate a state, we use data that'd a robot would not normally have access to.

# %%
class PurePursuitExpert:
    def __init__(self, env, ref_velocity=0.04, position_threshold=0.8, gain=10,
                 following_distance=0.3, max_iterations=1000):
        self.env = env.unwrapped
        self.following_distance = following_distance
        self.max_iterations = max_iterations
        self.ref_velocity = ref_velocity
        self.gain = gain
        self.position_threshold = position_threshold

    def predict(self, observation):  
        # Our expert drives with "cheating" data, something your implementation will not have access to
        closest_point, closest_tangent = self.env.closest_curve_point(self.env.cur_pos, self.env.cur_angle)

        iterations = 0
        lookup_distance = self.following_distance
        curve_point = None
        while iterations < self.max_iterations:
            # Project a point ahead along the curve tangent,
            # then find the closest point to to that
            follow_point = closest_point + closest_tangent * lookup_distance
            curve_point, _ = self.env.closest_curve_point(follow_point, self.env.cur_angle)

            # If we have a valid point on the curve, stop
            if curve_point is not None:
                break

            iterations += 1
            lookup_distance *= 0.5

        # Compute a normalized vector to the curve point
        point_vec = curve_point - self.env.cur_pos
        point_vec /= np.linalg.norm(point_vec)

        dot = np.dot(self.env.get_right_vec(), point_vec)
        steering = self.gain * -dot

        return self.ref_velocity, steering

# %%
nsteps = 100

# %%
local_env = launch_env()
local_env = wrap_env(local_env)
local_env = ResizeWrapper(local_env)
local_env = ImgWrapper(local_env)

local_env.reset()
wrapper = SteeringToWheelVelWrapper()

# Create an demonstrator
expert = PurePursuitExpert(env=local_env)

observations = []
actions = []

# Collect samples

for steps in range(0, nsteps):
    # use our 'expert' to predict the next action.
    action = expert.predict(None)
    action = wrapper.convert(action)
    observation, reward, done, info = local_env.step(action)
    observations.append(observation)
    actions.append(action)

    if done:
        local_env.reset()
        
local_env.close()

print('\nDone!\n')
# Out:
# 18:29:38|gym-duckietown|__init__.py:10|<module>(): gym-duckietown 5.0.12
#
# 18:29:40|dt-world|__init__.py:12|<module>(): duckietown-world 5.0.8
# 18:29:40|gym-duckietown|graphics.py:121|create_frame_buffers(): Falling back to non-multisampled frame buffer
# 18:29:40|gym-duckietown|graphics.py:121|create_frame_buffers(): Falling back to non-multisampled frame buffer
# 18:29:40|gym-duckietown|simulator.py:578|_load_map(): loading map file "/duckietown/simulation/src/gym_duckietown/maps/loop_empty.yaml"
# 18:29:40|gym-duckietown|objmesh.py:50|__init__(): loading mesh "duckiebot.obj"
# 18:29:40|gym-duckietown|objmesh.py:238|_load_mtl(): loading materials from "/duckietown/simulation/src/gym_duckietown/meshes/duckiebot.mtl"
# 18:29:41|gym-duckietown|graphics.py:60|load_texture(): loading texture "circlegrid.jpg"
# 18:29:42|gym-duckietown|objmesh.py:50|__init__(): loading mesh "duckie.obj"
# 18:29:42|gym-duckietown|graphics.py:60|load_texture(): loading texture "duckie.png"
# 18:29:42|gym-duckietown|objmesh.py:50|__init__(): loading mesh "cone.obj"
# 18:29:42|gym-duckietown|graphics.py:60|load_texture(): loading texture "cone.png"
# 18:29:42|gym-duckietown|graphics.py:60|load_texture(): loading texture "floor_1.png"
# 18:29:42|gym-duckietown|graphics.py:60|load_texture(): loading texture "curve_left_1.png"
# 18:29:43|gym-duckietown|graphics.py:60|load_texture(): loading texture "straight_1.png"
# 18:29:43|gym-duckietown|graphics.py:60|load_texture(): loading texture "curve_right_1.png"
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.13719561 0.         1.88880899] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.0873995 0.        1.9726338]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [4.03760339 0.         2.0564586 ]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [4.13719561 0.         1.88880899]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.98680973 0.         1.91287847]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.10908822 0.         2.30642426] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.0793971  0.         2.21355507]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [4.10908822 0.         2.30642426]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [4.04970598 0.         2.12068587]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.96795406 0.         2.24918441]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.47880119 0.         2.23809688] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.54467288 0.         2.16621385]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.47880119 0.         2.23809688]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.61054457 0.         2.09433082]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.45841324 0.         2.08716782]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.11902599 0.         2.07053136] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.05777514 0.         2.14639032]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [4.11902599 0.         2.07053136]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.99652428 0.         2.22224929]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [4.14880589 0.         2.21989135]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.11072664 0.         2.23740683] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.06163269 0.         2.15316887]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [4.11072664 0.         2.23740683]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [4.01253874 0.         2.0689309 ]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.96054713 0.         2.2120816 ]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.09719614 0.         2.20147659] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.00591875 0.         2.23575032]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [4.09719614 0.         2.20147659]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.91464137 0.         2.27002405]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [4.04704723 0.         2.34528318]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.48173779 0.         2.07668522] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.59826268 0.         2.08721855]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.5894849  0.         2.18432262]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.60704045 0.         1.99011448]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.48173779 0.         2.07668522]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.48172154 0.         1.84866924] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.57292165 0.         1.88314807]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.48172154 0.         1.84866924]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.66412176 0.         1.91762689]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.61429624 0.         1.77370793]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.50690495 0.         2.23654429] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.6172817  0.         2.19773742]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.64962075 0.         2.28971804]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.58494264 0.         2.10575679]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.50690495 0.         2.23654429]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.11050548 0.         2.28364106] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.00116556 0.         2.24200236]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [4.03586448 0.         2.15088576]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.96646664 0.         2.33311896]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [4.11050548 0.         2.28364106]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.50186974 0.         2.10261411] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.5769519  0.         2.04041348]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.50186974 0.         2.10261411]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.65203407 0.         1.97821284]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.50231114 0.         1.95031488]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.47260658 0.         1.77460142] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.58708306 0.         1.75043253]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.6072238 0.        1.8458296]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.56694232 0.         1.65503546]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.47260658 0.         1.77460142]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.09934153 0.         1.85301864] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.02300463 0.         1.79236447]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.94666773 0.         1.7317103 ]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [4.09934153 0.         1.85301864]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [4.09578963 0.         1.70076019]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.17105167 0.         1.80077003] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.09036721 0.         1.85550821]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [4.00968276 0.         1.9102464 ]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [4.17105167 0.         1.80077003]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [4.02468139 0.         1.75868687]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.49620504 0.         2.20742184] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.57500004 0.         2.14999713]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.49620504 0.         2.20742184]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.65379505 0.         2.09257242]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.50609039 0.         2.05544313]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.12972415 0.         2.27350789] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.022444   0.         2.32019802]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.98353555 0.         2.23079789]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [4.06135244 0.         2.40959815]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [4.12972415 0.         2.27350789]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.14789125 0.         1.98595245] corresponds to tile at (7, 3) which is not drivable: {'coords': (7, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.05139065 0.         1.99987665]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.95489004 0.         2.01380085]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [4.14789125 0.         1.98595245]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [4.0346816  0.         1.88407592]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.50005426 0.         1.72007355] corresponds to tile at (5, 2) which is not drivable: {'coords': (5, 2), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.58276167 0.         1.80282911]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.5137987  0.         1.87175196]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.65172464 0.         1.73390626]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.50005426 0.         1.72007355]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.49842474 0.         1.9311518 ] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.60040652 0.         1.87380448]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.64819596 0.         1.9587893 ]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.55261709 0.         1.78881966]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.49842474 0.         1.9311518 ]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [4.1279325  0.         2.40562151] corresponds to tile at (7, 4) which is not drivable: {'coords': (7, 4), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [4.04505092 0.         2.35427082]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.96216934 0.         2.30292013]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [4.1279325  0.         2.40562151]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [4.10667175 0.         2.25481292]
# 18:29:43|gym-duckietown|simulator.py:1140|_drivable_pos(): [3.4840149 0.        2.2828545] corresponds to tile at (5, 3) which is not drivable: {'coords': (5, 3), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:43|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:43|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:43|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [3.57730109 0.         2.31120829]
# 18:29:43|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [3.4840149 0.        2.2828545]
# 18:29:43|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [3.67058727 0.         2.33956208]
# 18:29:43|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [3.61132563 0.         2.19926486]
# 18:29:43|gym-duckietown|simulator.py:559|reset(): Starting at [3.89201099 0.         2.08907339] 1.6292900738092628
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Trying to monitor an environment which has no 'spec' set. This usually means you did not create it via 'gym.make', and is recommended only for advanced users.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# 18:29:48|gym-duckietown|simulator.py:1140|_drivable_pos(): [2.33703727 0.         2.57700384] corresponds to tile at (3, 4) which is not drivable: {'coords': (3, 4), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:48|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:48|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:48|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [2.33703727 0.         2.57700384]
# 18:29:48|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [2.24568806 0.         2.542922  ]
# 18:29:48|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [2.42838647 0.         2.61108568]
# 18:29:48|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [2.37793548 0.         2.46738479]
# 18:29:48|gym-duckietown|simulator.py:1140|_drivable_pos(): [2.28873639 0.         2.68406941] corresponds to tile at (3, 4) which is not drivable: {'coords': (3, 4), 'kind': 'floor', 'angle': 0, 'drivable': False, 'texture': <simulation.src.gym_duckietown.graphics.Texture object at 0x7f9ee1683b38>, 'color': array([1, 1, 1])}
# 18:29:48|gym-duckietown|simulator.py:1250|_valid_pose(): Invalid pose. Collision free: True On drivable area: False
# 18:29:48|gym-duckietown|simulator.py:1251|_valid_pose(): safety_factor: 1.3
# 18:29:48|gym-duckietown|simulator.py:1252|_valid_pose(): pos: [2.38071712 0.         2.71640816]
# 18:29:48|gym-duckietown|simulator.py:1253|_valid_pose(): l_pos: [2.28873639 0.         2.68406941]
# 18:29:48|gym-duckietown|simulator.py:1254|_valid_pose(): r_pos: [2.47269785 0.         2.74874692]
# 18:29:48|gym-duckietown|simulator.py:1255|_valid_pose(): f_pos: [2.41952363 0.         2.60603129]
# 18:29:48|gym-duckietown|simulator.py:559|reset(): Starting at [2.64153703 0.         2.88468928] 4.836049502872963
# Done!

# %%
view_results_ipython(local_env)
# Out:
#         <video width="360" height="auto" alt="test" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>

# %% [markdown]
# **<font color='red'>Question 2:</font> When you visualize the results, what are two major issues? Play with the expert's code and the execution code above, and list five changes that you tried, as well as their _qualitative_ effects on performance (i.e cover the most distance). DO NOT RESEED THE ENVIRONMENT**

# %% [markdown]
# # Defining a Model
#
# While the above expert isn't great, it's a start. What's best is that we now have image `observations` and real-valued `actions` that we can use to train a neural network in Pytorch. Our imitation learner will driver directly from observations, and will be trained with a popular imitation learning loss: Mean Squared Error.

# %%
class Model(nn.Module):
    def __init__(self, action_dim, max_action):
        super(Model, self).__init__()

        # TODO: You'll need to change this!
        flat_size = 0
        
        ###########################################
        # QUESTION 3. What does the next line do? #
        ###########################################
        self.lr = nn.LeakyReLU()
        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()

        self.conv1 = nn.Conv2d(3, 32, 8, stride=2)
        self.conv2 = nn.Conv2d(32, 32, 4, stride=2)

        self.bn1 = nn.BatchNorm2d(32)
        self.bn2 = nn.BatchNorm2d(32)

        self.dropout = nn.Dropout(.1)

        self.lin1 = nn.Linear(flat_size, 100)
        self.lin2 = nn.Linear(100, action_dim)

        self.max_action = max_action

    def forward(self, x):
        x = self.bn1(self.relu(self.conv1(x)))
        x = self.bn2(self.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)  # flatten
        x = self.dropout(x)
        x = self.lr(self.lin1(x))

        x = self.lin2(x)
        x = self.max_action * self.tanh(x)
        
        return x

# %% [markdown]
# # Training from the Teacher Data
#
# We can then write our _training loop_ : the piece of code that implements the process of stochastic gradient descent to minimize the loss between our network's predicted actions and those implemented by our expert.

# %%
nepochs = 5
batchsize = 10

actions = np.array(actions)
observations = np.array(observations)

model = Model(action_dim=2, max_action=1.)
model.train().to(device)

# weight_decay is L2 regularization, helps avoid overfitting
optimizer = optim.SGD(
    model.parameters(),
    lr=0.005,
    weight_decay=1e-3
)

avg_loss = 0
for epoch in range(nepochs):
    optimizer.zero_grad()

    batch_indices = np.random.randint(0, observations.shape[0], (batchsize))
    obs_batch = torch.from_numpy(observations[batch_indices]).float().to(device)
    act_batch = torch.from_numpy(actions[batch_indices]).float().to(device)

    model_actions = model(obs_batch)

    loss = (model_actions - act_batch).norm(2).mean()
    loss.backward()
    optimizer.step()

    loss = loss.data.item()
    avg_loss = avg_loss * 0.995 + loss * 0.005

    print('epoch %d, loss=%.3f' % (epoch, avg_loss))

    # Periodically save the trained model
    if epoch % 5 == 0:
        torch.save(model.state_dict(), 'models/imitate.pt')
        
print('\nDone!\n')

# %% [markdown]
# **<font color='red'>Question 3:</font> Qualitatively explain at least 2 changes you made to both the expert and network (architecture, hyperparameters, episode lengths, number of training episodes / epochs, etc.) (including partial points if we find that you didn't make changes to any part of our code - hyperparameters, network, etc.)**
#
#
# **<font color='red'>Question 4:</font> Explain the issues with the imitation learning loop above. Specifically, comment on the loss function and training objective. Explain at least one issue, and propose a way that could help solve the issues you've brought up.**

# %%
force_done(local_env)
local_env = launch_env()
local_env = wrap_env(local_env)
local_env = ResizeWrapper(local_env)
local_env = ImgWrapper(local_env)

obs = local_env.reset()

done = False
rewards = []
nsteps = 500
for steps in range(0, nsteps):
    obs = torch.from_numpy(obs).float().to(device).unsqueeze(0)
    action = model(obs)
    action = action.squeeze().data.cpu().numpy()
    obs, reward, done, info = local_env.step(action) 
    rewards.append(reward)
    
    if done:
        local_env.reset()
        print("Reset!")

print(info)
        
local_env.close()


print("\nDone!\n")

# %%
view_results_ipython(local_env)

# %% [markdown]
# **<font color='red'>Question 5:</font> Copy the value of _info_ , after simulating for 500 steps. If your simulation fails earlier, save the results _before_ the failure (i.e. when the simulation returns `done = True`.  DO NOT RESEED THE ENVIRONMENT**

# %% [markdown]
# # A nastier environment
#
# Once your solution is able to pass a curve while staying in the lane, you can try to see what happens if you modify the test environment with respect to the one used to generate the training dataset.
#
# To do this, create a new environment called *new_environment* by using the **launch_env()** function as above. This time passing the argument *domain_rand=True*. Basically it randomizes the environment. Once you have the new environment, run again the model without retraining.
#
# Then, visualize the results.
#
# **<font color='red'>Question 6:</font> Comment the performance of your solution on the new environment, name two reasons that justify the performance.**

# %%
# TODO: Run again the agent in the new randomized environment as explained above

new_env = launch_env(domain_rand=True)
new_env = wrap_env(new_env)
new_env = ResizeWrapper(new_env)
new_env = ImgWrapper(new_env)

obs = new_env.reset()

done = False
rewards = []
nsteps = 300
for steps in range(0, nsteps):
    obs = torch.from_numpy(obs).float().to(device).unsqueeze(0)
    action = model(obs)
    action = action.squeeze().data.cpu().numpy()
    obs, reward, done, info = new_env.step(action) 
    rewards.append(reward)
    
    if done:
        new_env.reset()

new_env.close()

print("\nDone!\n")

# %%
# TODO: visualize the results
view_results_ipython(new_env)
